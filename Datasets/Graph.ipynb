# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['LN', 'SVM', 'RF']
values = [0.9029436106871828, 0.828463019042137, 0.8165237202931374]

# Plotting the bar graph
plt.bar(categories, values)

# Adding labels and title
plt.xlabel('Machine Learning Algorithm')
plt.ylabel('R2 Score')
plt.title('Dataset - Desharnais')

# Displaying the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['LN', 'SVM', 'RF']
values = [123.26254616861536, 217.85361257150316, 233.01663660000077]

# Plotting the bar graph
plt.bar(categories, values)

# Adding labels and title
plt.xlabel('Machine Learning Algorithm')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Dataset - Desharnais')

# Displaying the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['LN', 'SVM', 'RF']
values = [9.782297146567906, 11.957477300633645, 10.508600000000005]

# Plotting the bar graph
plt.bar(categories, values)

# Adding labels and title
plt.xlabel('Machine Learning Algorithm')
plt.ylabel('Mean Absolute Error (MAE)')
plt.title('Dataset - Desharnais')

# Displaying the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['LN', 'SVM', 'RF']
values = [112.87346277253198, 46.81917712299543, 50.83819600650267]

# Plotting the bar graph
plt.bar(categories, values)

# Adding labels and title
plt.xlabel('Machine Learning Algorithm')
plt.ylabel('Mean Absolute Percentage Error (MAPE)')
plt.title('Dataset - Desharnais')

# Displaying the graph
plt.show()

# %%
# Creating a 2x2 figure
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))

# Subplot 1
categories1 = ['LN', 'SVM', 'RF']
values1 = [0.9029436106871828, 0.828463019042137, 0.8165237202931374]
axes[0, 0].bar(categories1, values1)
axes[0, 0].set_title('Dataset - Albrecht')
axes[0, 0].set_ylabel('R2 Score')

# Subplot 2
categories2 = ['LN', 'SVM', 'RF']
values2 = [123.26254616861536, 217.85361257150316, 233.01663660000077]
axes[0, 1].bar(categories2, values2)
axes[0, 1].set_title('Dataset - Albrecht')
axes[0, 1].set_ylabel('Mean Squared Error (MSE)')

# Subplot 3
categories3 = ['LN', 'SVM', 'RF']
values3 = [9.782297146567906, 11.957477300633645, 10.508600000000005]
axes[1, 0].bar(categories3, values3)
axes[1, 0].set_title('Dataset - Albrecht')
axes[1, 0].set_ylabel('Mean Absolute Error (MAE)')

# Subplot 4
categories4 = ['LN', 'SVM', 'RF']
values4 = [112.87346277253198, 46.81917712299543, 50.83819600650267]
axes[1, 1].bar(categories4, values4)
axes[1, 1].set_title('Dataset - Albrecht')
axes[1, 1].set_ylabel('Mean Absolute Percentage Error (MAPE)')

# Adjusting spacing between subplots
plt.tight_layout()

# Displaying the figure
plt.show()

# %%
# Creating a 2x2 figure
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))

# Subplot 1
categories1 = ['LN', 'SVM', 'RF']
values1 = [0.6991422903789932, 0.4628065411882959, 0.6430227768072897]
axes[0, 0].bar(categories1, values1)
axes[0, 0].set_title('Dataset - Desharnais')
axes[0, 0].set_ylabel('R2 Score')

# Subplot 2
categories2 = ['LN', 'SVM', 'RF']
values2 = [3838569.3478212766, 6853918.908849929, 4554584.386566158]
axes[0, 1].bar(categories2, values2)
axes[0, 1].set_title('Dataset - Desharnais')
axes[0, 1].set_ylabel('Mean Squared Error (MSE)')

# Subplot 3
categories3 = ['LN', 'SVM', 'RF']
values3 = [1457.0681616024547, 1711.6395159165047, 1631.1589351564407]
axes[1, 0].bar(categories3, values3)
axes[1, 0].set_title('Dataset - Desharnais')
axes[1, 0].set_ylabel('Mean Absolute Error (MAE)')

# Subplot 4
categories4 = ['LN', 'SVM', 'RF']
values4 = [54.98030928580311, 61.00505241859887, 84.18823740359532]
axes[1, 1].bar(categories4, values4)
axes[1, 1].set_title('Dataset - Desharnais')
axes[1, 1].set_ylabel('Mean Absolute Percentage Error (MAPE)')

# Adjusting spacing between subplots
plt.tight_layout()

# Displaying the figure
plt.show()

# %%
# Creating a 2x2 figure
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))

# Subplot 1
categories1 = ['LN', 'SVM', 'RF']
values1 = [0.33594902457859455, 0.40333728686427606, 0.3834602855023571]
axes[0, 0].bar(categories1, values1)
axes[0, 0].set_title('Dataset - China')
axes[0, 0].set_ylabel('R2 Score')

# Subplot 2
categories2 = ['LN', 'SVM', 'RF']
values2 = [19959774.273131978, 17934245.279627755, 18531700.106282998]
axes[0, 1].bar(categories2, values2)
axes[0, 1].set_title('Dataset - China')
axes[0, 1].set_ylabel('Mean Squared Error (MSE)')

# Subplot 3
categories3 = ['LN', 'SVM', 'RF']
values3 = [2222.1737050627517, 2068.350716843318, 2332.2703]
axes[1, 0].bar(categories3, values3)
axes[1, 0].set_title('Dataset - China')
axes[1, 0].set_ylabel('Mean Absolute Error (MAE)')

# Subplot 4
categories4 = ['LN', 'SVM', 'RF']
values4 = [193.55787249349342, 140.74819525147387, 192.39486134484181]
axes[1, 1].bar(categories4, values4)
axes[1, 1].set_title('Dataset - China')
axes[1, 1].set_ylabel('Mean Absolute Percentage Error (MAPE)')

# Adjusting spacing between subplots
plt.tight_layout()

# Displaying the figure
plt.show()
